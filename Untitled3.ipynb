# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelinat3/IP-CV_odd-Angelina-Thennessa-Jo-3/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Connecting drive and Github

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.pathes import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1041/3226070451.py in <cell line: 0>()
#       2 import pandas as pd
#       3 import cv2 as cv
# ----> 4 from google.colab.pathes import cv2_imshow # for image display
#       5 from skimage import io
#       6 from skimage import transform
#
# ModuleNotFoundError: No module named 'google.colab.pathes'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Angelinat3/IP-CV_odd-Angelina-Thennessa-Jo-3.git
# Out:
# fatal: destination path 'IP-CV_odd-Angelina-Thennessa-Jo-3' already exists and is not an empty directory.
